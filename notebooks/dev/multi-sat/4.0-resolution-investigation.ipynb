# %%
import autoroot
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import os
from glob import glob
from rs_tools._src.utils.io import get_list_filenames


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
msg_path = '/mnt/disks/data/miniset/msg/geoprocessed'
goes_path = '/mnt/disks/data/miniset/goes16/geoprocessed'

# %%
goes_filenames = get_list_filenames(goes_path, ext='nc')
msg_filenames = get_list_filenames(msg_path, ext='nc')

# %%
print(msg_filenames[2])
print(goes_filenames[2])
# Out:
# /mnt/disks/data/miniset/msg/geoprocessed/20201001151243_msg.nc
# /mnt/disks/data/miniset/goes16/geoprocessed/20201001150019_goes16.nc

# %%
msg_test = xr.open_dataset(msg_filenames[2])
goes_test = xr.open_dataset(goes_filenames[2])

# %%
plt.imshow(msg_test.Rad.data[0])

# %%
plt.imshow(goes_test.Rad.data[0])

# %%
print(goes_test.latitude.compute().min())
print(goes_test.latitude.compute().max())
print(goes_test.longitude.compute().min())
print(goes_test.longitude.compute().max())
# Out:
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(0.00464154)
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(39.98519969)
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-44.99025902)
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-20.04057225)

# %%
print(msg_test.latitude.compute().min())
print(msg_test.latitude.compute().max())
print(msg_test.longitude.compute().min())
print(msg_test.longitude.compute().max())
# Out:
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(0.)
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(44.90658452)
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-78.44849834)
# <xarray.DataArray 'longitude' ()> Size: 8B
# array(-14.55963817)
