# %% [markdown]
# # Downloading GOES data using the goes2go package
# https://github.com/blaylockbk/goes2go

# %% [markdown]
# ## installing goes2go package

# %%
! pip install goes2go
# Out:
# Collecting goes2go
#   Downloading goes2go-2023.8.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: s3fs>=2023.6.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from goes2go) (2023.10.0)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from goes2go) (1.5.0)
# Collecting metpy
#   Downloading MetPy-1.5.1-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.5/400.5 kB 8.0 MB/s eta 0:00:0000:01
# Collecting cartopy>=0.22.0
#   Downloading Cartopy-0.22.0-cp310-cp310-macosx_10_9_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 8.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: xarray in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from goes2go) (2022.9.0)
# Collecting h5netcdf
#   Downloading h5netcdf-1.3.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from goes2go) (3.5.2)
# Requirement already satisfied: numpy in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from goes2go) (1.23.3)
# Collecting pyproj>=3.1.0
#   Downloading pyproj-3.6.1-cp310-cp310-macosx_10_9_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 8.3 MB/s eta 0:00:0000:0100:01m
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.5 MB/s eta 0:00:00
# Collecting shapely>=1.7
#   Downloading shapely-2.0.2-cp310-cp310-macosx_10_9_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.0 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: packaging>=20 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from cartopy>=0.22.0->goes2go) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from matplotlib->goes2go) (0.11.0)
# Requirement already satisfied: aiobotocore~=2.7.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from s3fs>=2023.6.0->goes2go) (2.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from s3fs>=2023.6.0->goes2go) (3.9.1)
# Requirement already satisfied: fsspec==2023.10.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from s3fs>=2023.6.0->goes2go) (2023.10.0)
# Collecting h5py
#   Downloading h5py-3.10.0-cp310-cp310-macosx_10_9_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Collecting pooch>=1.2.0
#   Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.7 MB/s eta 0:00:00
# Collecting scipy>=1.4.0
#   Downloading scipy-1.11.4-cp310-cp310-macosx_10_9_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 8.7 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: traitlets>=5.0.5 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from metpy->goes2go) (5.1.1)
# Collecting pint>=0.15
#   Downloading Pint-0.22-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from pandas->goes2go) (2022.4)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs>=2023.6.0->goes2go) (0.11.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs>=2023.6.0->goes2go) (1.16.0)
# Requirement already satisfied: botocore<1.31.65,>=1.31.16 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs>=2023.6.0->goes2go) (1.31.64)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (1.9.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.6.0->goes2go) (23.1.0)
# Requirement already satisfied: typing-extensions in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from pint>=0.15->metpy->goes2go) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from pooch>=1.2.0->metpy->goes2go) (2.28.1)
# Collecting platformdirs>=2.5.0
#   Downloading platformdirs-4.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from pyproj>=3.1.0->cartopy>=0.22.0->goes2go) (2022.9.24)
# Requirement already satisfied: six>=1.5 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->goes2go) (1.16.0)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs>=2023.6.0->goes2go) (1.26.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs>=2023.6.0->goes2go) (1.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.2.0->metpy->goes2go) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/lillifreischem/miniconda3/envs/gcmodel/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.2.0->metpy->goes2go) (2.1.1)
# Installing collected packages: toml, shapely, scipy, pyshp, pyproj, platformdirs, pint, h5py, pooch, h5netcdf, cartopy, metpy, goes2go
# Successfully installed cartopy-0.22.0 goes2go-2023.8.0 h5netcdf-1.3.0 h5py-3.10.0 metpy-1.5.1 pint-0.22 platformdirs-4.0.0 pooch-1.8.0 pyproj-3.6.1 pyshp-2.3.1 scipy-1.11.4 shapely-2.0.2 toml-0.10.2

# %% [markdown]
# ## downloading data using goes2go

# %%
from goes2go import GOES

# ABI Level 1b Data
G = GOES(satellite=16, product="ABI-L1b-Rad", domain='F')

# %%
# download the data nearest a specific time
files = G.nearesttime('2018-10-02 17:00', return_as='filelist')#, save_dir=None)
# Out:
# 📦 Finished downloading [16] files to [/home/juanjohn/data/noaa-goes16/ABI-L1b-RadF].

# %%
files.file[0]
# Out:
# 'noaa-goes16/ABI-L1b-RadF/2018/275/17/OR_ABI-L1b-RadF-M3C12_G16_s20182751700369_e20182751711142_c20182751711204.nc'

# %% [markdown]
# ## plot the 16 channels

# %%
import xarray as xr
import os
import matplotlib.pyplot as plt

# %%
datadir = './data/noaa-goes16/ABI-L1b-RadF/2018/274/17/'
channels = os.listdir(datadir)
channels.sort()

# %%
plt.imshow(xr.load_dataset(datadir + channels[0]).Rad)
plt.title('Channel 1')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[2]).Rad)
plt.title('Channel 3')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[3]).Rad)
plt.title('Channel 4')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[4]).Rad)
plt.title('Channel 5')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[5]).Rad)
plt.title('Channel 7')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[6]).Rad)
plt.title('Channel 8')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[7]).Rad)
plt.title('Channel 9')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[8]).Rad)
plt.title('Channel 10')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[9]).Rad)
plt.title('Channel 11')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[10]).Rad)
plt.title('Channel 12')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[11]).Rad)
plt.title('Channel 13')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[12]).Rad)
plt.title('Channel 14')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[13]).Rad)
plt.title('Channel 15')
plt.show()

# %%
plt.imshow(xr.load_dataset(datadir + channels[14]).Rad)
plt.title('Channel 16')
plt.show()
# Out:
# Text(0.5, 1.0, 'Channel 16')
